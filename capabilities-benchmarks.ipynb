# %%
import pandas as pd

data = {
    "Capability": [
        "Episodic memory",
        "Semantic memory",
        "Procedural memory",
        "Prospective memory",
        "Working memory",
        "Inhibitory control",
        "Cognitive flexibility",
        "Planning",
        "Metacognition",
        "Perception",
        "Attribution",
        "Object permanence",
        "Causal reasoning",
        "Affordances",
        "Mental simulation",
        "Spatial navigation",
        "Communication"
    ],
    "Benchmarks": [
        "NarrativeQA, CoQA, Abstract Narrative Understanding, Cosmos QA, Animal AI",
        "GRE Reading Comprehension, SocialIQA, CoQA, Keyword Sentence Transformation, ROPES",
        "PlanBench, EmbodiedQA",
        "PlanBench, Text Navigation Game",
        "HotpotQA, PlanBench, ReClor, NarrativeQA, CoQA",
        "ReClor, Animal AI, DISFL-QA",
        "PlanBench, MBench, Animal AI, WANLI, Question Selection",
        "PlanBench, EmbodiedQA, Room-to-Room",
        "MBench, OpenToM, SocialIQA, ToMi",
        "VQA 2.0, DAQUAR, COCO-QA, Animal AI",
        "SocialIQA, OpenToM, FANToM, Causal Judgment, Cause and Effect",
        "O-PIAAGET, LA-CATER",
        "Causal Judgment, Cosmos QA, COPA, ROPES, Animal AI",
        "3D AffordanceNet, Animal AI",
        "Animal AI, StepGame, CLadder, COPA",
        "EmbodiedQA, Room-to-Room, Animal AI",
        "CoQA, Social Support, SocialIQA, DISFL-QA, TalkDown"
    ]
}

# Create a DataFrame
capabilities_benchmarks = pd.DataFrame(data)
capabilities_benchmarks
# Out:
#                Capability                                         Benchmarks
# 0         Episodic memory  NarrativeQA, CoQA, Abstract Narrative Understa...
# 1         Semantic memory  GRE Reading Comprehension, SocialIQA, CoQA, Ke...
# 2       Procedural memory                              PlanBench, EmbodiedQA
# 3      Prospective memory                    PlanBench, Text Navigation Game
# 4          Working memory     HotpotQA, PlanBench, ReClor, NarrativeQA, CoQA
# 5      Inhibitory control                        ReClor, Animal AI, DISFL-QA
# 6   Cognitive flexibility  PlanBench, MBench, Animal AI, WANLI, Question ...
# 7                Planning                PlanBench, EmbodiedQA, Room-to-Room
# 8           Metacognition                   MBench, OpenToM, SocialIQA, ToMi
# 9              Perception                VQA 2.0, DAQUAR, COCO-QA, Animal AI
# 10            Attribution  SocialIQA, OpenToM, FANToM, Causal Judgment, C...
# ...
